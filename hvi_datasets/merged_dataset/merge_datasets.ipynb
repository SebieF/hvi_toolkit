# %%
import os, sys
dir2 = os.path.abspath('')
dir1 = os.path.dirname(dir2)
if not dir1 in sys.path: sys.path.append(dir1)

from hvi_datasets.taxonomy.taxonomy import Taxonomy
from hvi_datasets.interaction_datasets import DatasetHVIDB, DatasetHPIDBVirus, DatasetIntactPositive, DatasetVirusMentha, DatasetVirHostNet3, DatasetVirusesString, DatasetSarsCov2IM28880, DatasetTsukiyamaNegatives

# %%
taxonomy = Taxonomy(hvidb_path="../raw_data/hvidb/HVIDB_PPIs.txt", ncbi_taxonomy_path="../raw_data/taxonomy/names_taxonomy.tsv")

# %% [markdown]
# ### Positive datasets

# %%
hvidb = DatasetHVIDB(file_path="../raw_data/hvidb/HVIDB_PPIs.txt")
hvidb_std = hvidb.to_standardized_dataset(taxonomy=taxonomy)
hvidb_std.data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48643 entries, 0 to 48642
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Uniprot_human  48643 non-null  string
#  1   Uniprot_virus  48643 non-null  string
#  2   Taxon_virus    48643 non-null  string
#  3   Dataset        48643 non-null  string
#  4   Experimental   48643 non-null  string
#  5   Target         48643 non-null  string
#  6   Family_virus   48643 non-null  object
# dtypes: object(1), string(6)
# memory usage: 2.6+ MB

# %%
hpidb = DatasetHPIDBVirus(file_path="../raw_data/hpidb/hpidb_virus_25_10_22.txt")
hpidb_std = hpidb.to_standardized_dataset(taxonomy=taxonomy)
hpidb_std.data_frame.info()
# Out:
# Dropped 8136 duplicated interactions from standardized:hpidb_virus! Ids[0-5]: [(2, 3), (2, 13), (2, 16), (2, 17), (4, 20)]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31728 entries, 0 to 31727
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Uniprot_human  31728 non-null  string
#  1   Uniprot_virus  31728 non-null  string
#  2   Taxon_virus    31728 non-null  string
#  3   Dataset        31728 non-null  string
#  4   Experimental   31728 non-null  string
#  5   Target         31728 non-null  string
#  6   Family_virus   31728 non-null  object
# dtypes: object(1), string(6)
# memory usage: 1.7+ MB

# %%
intact = DatasetIntactPositive(file_path="../raw_data/intact/intact_positive_human_virus.txt")
intact_std = intact.to_standardized_dataset(taxonomy=taxonomy)
intact_std.data_frame.info()
# Out:
# Dropped 9028 duplicated interactions from standardized:intact_positive! Ids[0-5]: [(0, 1), (0, 2), (3, 4155), (3, 4156), (4, 4175)]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26558 entries, 0 to 26557
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Uniprot_human  26558 non-null  string
#  1   Uniprot_virus  26558 non-null  string
#  2   Taxon_virus    26558 non-null  string
#  3   Dataset        26558 non-null  string
#  4   Experimental   26558 non-null  string
#  5   Target         26558 non-null  string
#  6   Family_virus   26558 non-null  object
# dtypes: object(1), string(6)
# memory usage: 1.4+ MB

# %%
virus_mentha = DatasetVirusMentha(file_path="../raw_data/virus_mentha/virus_mentha_human_virus_9606.csv")
virus_mentha_std = virus_mentha.to_standardized_dataset(taxonomy=taxonomy)
virus_mentha_std.data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10692 entries, 0 to 10691
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Uniprot_human  10692 non-null  string
#  1   Uniprot_virus  10692 non-null  string
#  2   Taxon_virus    10692 non-null  string
#  3   Dataset        10692 non-null  string
#  4   Experimental   10692 non-null  string
#  5   Target         10692 non-null  string
#  6   Family_virus   10692 non-null  object
# dtypes: object(1), string(6)
# memory usage: 584.8+ KB

# %%
vir_host_net_3 = DatasetVirHostNet3(file_path="../raw_data/vir_host_net_3/VirHostNet3.tsv")
vir_host_net_3_std = vir_host_net_3.to_standardized_dataset(taxonomy=taxonomy)
vir_host_net_3_std.data_frame.info()
# Out:
# Dropped 10652 human-human interactions from standardized:vir_host_net3! Ids[0-5]: [26, 27, 34, 35, 50]
# Dropped 4045 duplicated interactions from standardized:vir_host_net3! Ids[0-5]: [(7, 8), (27, 28), (41, 42), (44, 45), (46, 47)]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36795 entries, 0 to 36794
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Uniprot_human  36795 non-null  string
#  1   Uniprot_virus  36795 non-null  string
#  2   Taxon_virus    36795 non-null  string
#  3   Dataset        36795 non-null  string
#  4   Experimental   36795 non-null  string
#  5   Target         36795 non-null  string
#  6   Family_virus   36795 non-null  object
# dtypes: object(1), string(6)
# memory usage: 2.0+ MB

# %%
viruses_string = DatasetVirusesString(file_path="../raw_data/viruses_string/9606.protein.links.detailed.v10.5.txt")
viruses_string_std = viruses_string.to_standardized_dataset(taxonomy=taxonomy)
viruses_string_std.data_frame.info()
# Out:
# Dropped 19903 unknown ids from viruses_string dataset!
# Dropped 165 duplicated interactions from standardized:viruses_string! Ids[0-5]: [(6420, 39026), (6420, 40394), (6420, 50751), (6420, 50785), (6421, 39034)]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63941 entries, 0 to 63940
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Uniprot_human  63941 non-null  string
#  1   Uniprot_virus  63941 non-null  string
#  2   Taxon_virus    63941 non-null  string
#  3   Dataset        63941 non-null  string
#  4   Experimental   63941 non-null  string
#  5   Target         63941 non-null  string
#  6   Family_virus   63941 non-null  object
# dtypes: object(1), string(6)
# memory usage: 3.4+ MB

# %%
sars_cov_2_im_28880 = DatasetSarsCov2IM28880(file_path="../raw_data/sars_cov_2_im28880/IM_28880_sars_2510.txt")
sars_cov_2_im_28880_std = sars_cov_2_im_28880.to_standardized_dataset(taxonomy=taxonomy)
sars_cov_2_im_28880_std.data_frame.info()
# Out:
# Dropped 359 duplicated interactions from standardized:sars_cov_2_im28880! Ids[0-5]: [(0, 240), (0, 360), (1, 239), (1, 361), (2, 219)]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Uniprot_human  205 non-null    string
#  1   Uniprot_virus  205 non-null    string
#  2   Taxon_virus    205 non-null    string
#  3   Dataset        205 non-null    string
#  4   Experimental   205 non-null    string
#  5   Target         205 non-null    string
#  6   Family_virus   205 non-null    object
# dtypes: object(1), string(6)
# memory usage: 11.3+ KB

# %%
# Merge all standardized datasets (only positive)
merged_dataset_positives = hvidb_std.merge_with_standardized_dataset(hpidb_std).merge_with_standardized_dataset(intact_std).merge_with_standardized_dataset(virus_mentha_std).merge_with_standardized_dataset(vir_host_net_3_std).merge_with_standardized_dataset(viruses_string_std).merge_with_standardized_dataset(sars_cov_2_im_28880_std)
merged_dataset_positives.data_frame.info()
# Out:
# Dropped 31364 duplicated interactions from standardized:standardized:hvidb;standardized:hpidb_virus! Ids[0-5]: [(0, 60030), (2, 57651), (3, 74674), (5, 67756), (7, 63114)]
# Dropped 15172 duplicated interactions from standardized:standardized:standardized:hvidb;standardized:hpidb_virus;standardized:intact_positive! Ids[0-5]: [(3, 60936), (8, 49636), (9, 55343), (17, 50198), (19, 55743)]
# Dropped 10226 duplicated interactions from standardized:standardized:standardized:standardized:hvidb;standardized:hpidb_virus;standardized:intact_positive;standardized:virus_mentha! Ids[0-5]: [(9, 67529), (19, 63584), (20, 64933), (21, 67955), (22, 68257)]
# Dropped 27256 duplicated interactions from standardized:standardized:standardized:standardized:standardized:hvidb;standardized:hpidb_virus;standardized:intact_positive;standardized:virus_mentha;standardized:vir_host_net3! Ids[0-5]: [(0, 92738), (2, 67081), (5, 73714), (7, 64980), (9, 89271)]
# Dropped 4641 duplicated interactions from standardized:standardized:standardized:standardized:standardized:standardized:hvidb;standardized:hpidb_virus;standardized:intact_positive;standardized:virus_mentha;standardized:vir_host_net3;standardized:viruses_string! Ids[0-5]: [(9, 132992), (19, 80860), (43, 108899), (49, 124836), (51, 118609)]
# Dropped 205 duplicated interactions from standardized:standardized:standardized:standardized:standardized:standardized:standardized:hvidb;standardized:hpidb_virus;standardized:intact_positive;standardized:virus_mentha;standardized:vir_host_net3;standardized:viruses_string;standardized:sars_cov_2_im28880! Ids[0-5]: [(48380, 129701), (48387, 129700), (49222, 129698), (49223, 129699), (49224, 129702)]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129698 entries, 0 to 129697
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Uniprot_human  129698 non-null  string
#  1   Uniprot_virus  129698 non-null  string
#  2   Taxon_virus    129698 non-null  string
#  3   Dataset        129698 non-null  string
#  4   Experimental   129698 non-null  string
#  5   Target         129698 non-null  string
#  6   Family_virus   129698 non-null  string
# dtypes: string(7)
# memory usage: 6.9 MB

# %%
merged_dataset_positives.plot_uniques_by_datasets()
# Out:
# Unique interactions in dataset (experimental=False)
# {'virus_mentha': [466], 'sars_cov_2_im28880': [0], 'hvidb': [13723], 'viruses_string': [59300], 'hpidb_virus': [106], 'vir_host_net3': [9514], 'intact_positive': [6877]}

# %%
merged_dataset_positives.store(file_path="merged_dataset_positives.csv")

# %% [markdown]
# ### Negative dataset

# %%
tsukiyama_negatives = DatasetTsukiyamaNegatives(file_path="../raw_data/negatives/negative_samples.csv", fasta_file="../raw_data/negatives/tsukiyama_negatives_with_taxon.fasta")
tsukiyama_negatives_std = tsukiyama_negatives.to_standardized_dataset(taxonomy=taxonomy)
tsukiyama_negatives_std.data_frame.info()
# Out:
# Successfully assigned virus taxa to tsukiyama negatives dataset!
# Unknown ids: 3, {'F1BA49', 'Q76VT2', 'P34015'}
# ['54315', '10299', '128952', '11723', '648242']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209046 entries, 0 to 209045
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Uniprot_human  209046 non-null  string
#  1   Uniprot_virus  209046 non-null  string
#  2   Taxon_virus    209046 non-null  string
#  3   Dataset        209046 non-null  string
#  4   Experimental   209046 non-null  string
#  5   Target         209046 non-null  string
#  6   Family_virus   209046 non-null  object
# dtypes: object(1), string(6)
# memory usage: 11.2+ MB

# %%
merged_dataset_complete = merged_dataset_positives.merge_with_standardized_dataset(tsukiyama_negatives_std)
merged_dataset_complete.data_frame.info()
# Out:
# Dropped 167 duplicated interactions from standardized:standardized:standardized:standardized:standardized:standardized:standardized:standardized:hvidb;standardized:hpidb_virus;standardized:intact_positive;standardized:virus_mentha;standardized:vir_host_net3;standardized:viruses_string;standardized:sars_cov_2_im28880;standardized:tsukiyama_negatives! Ids[0-5]: [(444, 160379), (653, 244603), (1573, 168444), (3664, 292430), (4133, 291990)]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338577 entries, 0 to 338576
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Uniprot_human  338577 non-null  string
#  1   Uniprot_virus  338577 non-null  string
#  2   Taxon_virus    338577 non-null  string
#  3   Dataset        338577 non-null  string
#  4   Experimental   338577 non-null  string
#  5   Target         338577 non-null  string
#  6   Family_virus   338577 non-null  string
# dtypes: string(7)
# memory usage: 18.1 MB

# %%
merged_dataset_complete.plot_uniques_by_datasets()
# Out:
# Unique interactions in dataset (experimental=False)
# {'virus_mentha': [466], 'sars_cov_2_im28880': [0], 'tsukiyama_negatives': [208879], 'hvidb': [13715], 'viruses_string': [59152], 'hpidb_virus': [106], 'vir_host_net3': [9514], 'intact_positive': [6877]}

# %%
# Get all sequences:
fasta_file_path = merged_dataset_complete.download_sequences_from_uniprot()
# Out:
# Downloading 25442 protein sequences!
#   0%|          | 2/1273 [00:11<1:59:35,  5.65s/it]
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Get all sequences:
# ----> 2 fasta_file_path = merged_dataset_complete.download_sequences_from_uniprot()
#
# File ~/PycharmProjects/lyssa_predict/hvi_datasets/dataset_base_classes/hvi_standardized_dataset.py:279, in DatasetHVIStandardized.download_sequences_from_uniprot(self)
#     276 unique_ids = self.get_unique_proteins()
#     278 print(f"Downloading {len(unique_ids)} protein sequences!")
# --> 279 sequence_dict = self._get_sequences_with_ptm_information(uniprot_list=unique_ids)
#     280 fasta_file_path = f"downloaded_dataset_{self.name.replace('standardized:', '')}.fasta"
#     281 with open(fasta_file_path, "w") as fasta_file:
#
# File ~/PycharmProjects/lyssa_predict/hvi_datasets/dataset_base_classes/hvi_abstract_dataset.py:153, in DatasetHVI._get_sequences_with_ptm_information(uniprot_list)
#     150 else:
#     151     # Extract the response body and parse it as JSON
#     152     response_body = r.text
# --> 153     response_json = json.loads(response_body)
#     154     # Iterate over each UniProt entry in the response
#     155     for response in response_json:
#
# File ~/anaconda3/envs/bio_poetry/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/anaconda3/envs/bio_poetry/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/anaconda3/envs/bio_poetry/lib/python3.9/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 1 column 867373 (char 867372)

# %%
fasta_string_dropped, merged_dataset_complete_cleaned = merged_dataset_complete.remove_unavailable_and_overlong_sequences(fasta_file_path=fasta_file_path)
# Out:
# Removing 104 non-matching ids: ['P35544', 'A0A0A0MT49', 'B4URF5', 'P30484', 'Q2KRY9', 'Q95604', 'A0A087WWT0', 'P04544', 'P30493', 'P30504', 'K7EP68', 'P01892', 'P30491', 'P30508', 'P30495', 'H0Y4G9', 'A0A087X2G6', 'A0A087X231', 'F2Z2X4', 'A0A0A0MSG2', 'D3DNK7', 'Q96SH1', 'Q29940', 'Q9PY23', 'P03074', 'A0A0A0MR88', 'F5GX77', 'C9JDS9', 'E9KL23', 'P30510', 'A8K3E0', 'P68320', 'F8WB74', 'P08107', 'Q2KRY6', 'Q8WZ42', 'A0A0A0MTI5', 'P03076', 'P30460', 'A0A087WVE2', 'Q31612', 'Q2VP98', 'Q2MG97', 'O56652', 'P62158', 'P18465', 'Q9TNN7', 'Q13727', 'C9JIZ6', 'Q1I2B4', 'P30459', 'A0A087WUL9', 'D6RB85', 'A0A0A0MSE7', 'E7EW20', 'P30443', 'Q13748', 'E7EQR4', 'A0A3B3IS20', 'P05534', 'P30505', 'P0CG05', 'A0A087WV22', 'A0A0A0MSJ9', 'P0CG06', 'A0A087X117', 'Q9WMX2', 'M0R0H3', 'P13760', 'A0A1W2PQ51', 'P10319', 'Q86UA3', 'H7BY58', 'D3DTX6', 'Q85737', 'P62988', 'Q1HVD9', 'Q777A4', 'P30685', 'P30488', 'E7ERX5', 'Q87644', 'B4E273', 'G8HBH4', 'A0A0D9SF60', 'Q30KQ2', 'H0YJ75', 'O43392', 'P0DN76', 'P13746', 'P30492', 'P01891', 'P63233', 'Q29963', 'Q91QP4', 'Q86UT2', 'A0A0A0MT60', 'Q85406', 'A0A0A0MTS7', 'Q1I2B3', 'A0A0U1RRH6', 'Q29960', 'P30464', 'P63231']
# Removing 0 overlong ids: []

# %%
merged_dataset_complete_cleaned.store(file_path="merged_dataset_complete.csv")

# %%
with open("merged_dataset_complete.fasta", "w") as merged_dataset_complete_fasta:
    merged_dataset_complete_fasta.write(fasta_string_dropped)
